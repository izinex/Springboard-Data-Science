# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import os
import seaborn as sns
import scipy.stats as stats
import matplotlib.ticker as tick
import sklearn.model_selection

from operator import itemgetter
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import OrdinalEncoder
from category_encoders.target_encoder import TargetEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import (GradientBoostingRegressor, GradientBoostingClassifier)
import xgboost as xgb

import featuretools as ft
from sklearn import neighbors, datasets, preprocessing
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, learning_curve

# %%
df = pd.read_csv('ny_eda_data.csv')
df = df.drop(['City', 'address/streetAddress', 'ParkingType', 'school_1_grades', 'school_1_level'
             ,'school_1_type', 'school_2_level', 'school_2_type'], axis=1)

# %%
df.HomeType = pd.Categorical(df.HomeType)
df.HomeType = df.HomeType.cat.codes

# %%
print(df.shape)
print(df.describe())
print(df.dtypes)
# Out:
# (62456, 24)
#             ZipCode      latitude     livingArea     longitude         price  \
# count  62449.000000  62455.000000   55035.000000  62455.000000  6.245600e+04
# mean   10902.516630     40.694577    3378.404379    -73.930004  9.250491e+05
# std      515.536308      0.095875   18247.884500      0.135142  9.186984e+05
# min      148.000000     40.498634       1.000000    -74.255333  1.000000e+05
# 25%    10314.000000     40.614168    1300.000000    -74.001343  5.050000e+05
# 50%    11209.000000     40.692322    1813.000000    -73.905731  6.972275e+05
# 75%    11367.000000     40.756136    2530.000000    -73.829376  9.750000e+05
# max    13277.000000     40.912682  986641.000000    -73.700432  1.000000e+07
#
#        priceChangeRate  propertyTaxRate      HomeType     YearBuilt  \
# count     6.199000e+04     62443.000000  62456.000000  58506.000000
# mean      4.768525e+02         0.826273      7.472172   1947.972926
# std       1.938993e+04         0.097421      2.811090     33.340796
# min      -9.999979e-01         0.650000      0.000000   1280.000000
# 25%      -4.008016e-02         0.840000      6.000000   1925.000000
# 50%       0.000000e+00         0.840000      8.000000   1940.000000
# 75%       0.000000e+00         0.870000     10.000000   1970.000000
# max       2.649999e+06         2.370000     11.000000   2021.000000
#
#        Full_Bathrooms  ...    Annual_Tax  Tax_Assessed_Value  \
# count    47882.000000  ...  5.360400e+04        5.174300e+04
# mean         1.934589  ...  1.934875e+04        1.170319e+06
# std          1.460586  ...  1.697608e+05        9.141447e+06
# min          0.000000  ...  0.000000e+00        1.000000e+00
# 25%          1.000000  ...  4.387750e+03        4.980000e+05
# 50%          2.000000  ...  5.774000e+03        6.400000e+05
# 75%          3.000000  ...  7.605000e+03        9.098000e+05
# max         70.000000  ...  1.458491e+07        1.680558e+09
#
#        school_1_distance  school_1_rating  school_1_size  school_1_s/t_ratio  \
# count       62371.000000     61657.000000   61983.000000        61532.000000
# mean            0.388798         6.309795     737.011826           13.987356
# std             0.326365         2.115094     298.282379            2.064922
# min             0.000000         1.000000     115.000000            6.000000
# 25%             0.200000         5.000000     540.000000           13.000000
# 50%             0.300000         7.000000     692.000000           14.000000
# 75%             0.500000         8.000000     914.000000           15.000000
# max             8.500000        10.000000    2000.000000           20.000000
#
#        school_2_distance  school_2_rating  school_2_size  school_2_s/t_ratio
# count       61750.000000     61566.000000   61537.000000        60089.000000
# mean            0.905045         5.663873    1010.768920           14.400423
# std             0.751881         2.234045     677.695871            2.393513
# min             0.000000         1.000000      85.000000            7.000000
# 25%             0.400000         4.000000     513.000000           13.000000
# 50%             0.700000         6.000000     973.000000           14.000000
# 75%             1.200000         7.000000    1363.000000           16.000000
# max             8.300000        10.000000    5839.000000           24.000000
#
# [8 rows x 24 columns]
# ZipCode               float64
# latitude              float64
# livingArea            float64
# longitude             float64
# price                 float64
# priceChangeRate       float64
# propertyTaxRate       float64
# HomeType                 int8
# YearBuilt             float64
# Full_Bathrooms        float64
# Half_Bathrooms        float64
# Bedrooms              float64
# Lot_Size              float64
# Story_Building        float64
# Annual_Tax            float64
# Tax_Assessed_Value    float64
# school_1_distance     float64
# school_1_rating       float64
# school_1_size         float64
# school_1_s/t_ratio    float64
# school_2_distance     float64
# school_2_rating       float64
# school_2_size         float64
# school_2_s/t_ratio    float64
# dtype: object

# %%
# Let's check the distribution of our features to better understand a better type of imputation
fig = plt.figure(figsize = (20,25))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# array([[<AxesSubplot:title={'center':'ZipCode'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'livingArea'}>,
#         <AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'price'}>],
#        [<AxesSubplot:title={'center':'priceChangeRate'}>,
#         <AxesSubplot:title={'center':'propertyTaxRate'}>,
#         <AxesSubplot:title={'center':'HomeType'}>,
#         <AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'Full_Bathrooms'}>],
#        [<AxesSubplot:title={'center':'Half_Bathrooms'}>,
#         <AxesSubplot:title={'center':'Bedrooms'}>,
#         <AxesSubplot:title={'center':'Lot_Size'}>,
#         <AxesSubplot:title={'center':'Story_Building'}>,
#         <AxesSubplot:title={'center':'Annual_Tax'}>],
#        [<AxesSubplot:title={'center':'Tax_Assessed_Value'}>,
#         <AxesSubplot:title={'center':'school_1_distance'}>,
#         <AxesSubplot:title={'center':'school_1_rating'}>,
#         <AxesSubplot:title={'center':'school_1_size'}>,
#         <AxesSubplot:title={'center':'school_1_s/t_ratio'}>],
#        [<AxesSubplot:title={'center':'school_2_distance'}>,
#         <AxesSubplot:title={'center':'school_2_rating'}>,
#         <AxesSubplot:title={'center':'school_2_size'}>,
#         <AxesSubplot:title={'center':'school_2_s/t_ratio'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
X = df.drop([ 'price'] ,axis=1)
y = df.price

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=100)

# %%
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count', '%'])
# Out:
#                     count          %
# price                   0   0.000000
# HomeType                0   0.000000
# latitude                1   0.001601
# longitude               1   0.001601
# ZipCode                 7   0.011208
# propertyTaxRate        13   0.020815
# school_1_distance      85   0.136096
# priceChangeRate       466   0.746125
# school_1_size         473   0.757333
# school_2_distance     706   1.130396
# school_1_rating       799   1.279301
# school_2_rating       890   1.425003
# school_2_size         919   1.471436
# school_1_s/t_ratio    924   1.479442
# school_2_s/t_ratio   2367   3.789868
# YearBuilt            3950   6.324452
# livingArea           7421  11.881965
# Annual_Tax           8852  14.173178
# Lot_Size             9441  15.116242
# Tax_Assessed_Value  10713  17.152876
# Bedrooms            12177  19.496926
# Half_Bathrooms      14511  23.233957
# Full_Bathrooms      14574  23.334828
# Story_Building      23429  37.512809

# %%
df.dtypes
# Out:
# ZipCode               float64
# latitude              float64
# livingArea            float64
# longitude             float64
# price                 float64
# priceChangeRate       float64
# propertyTaxRate       float64
# HomeType                 int8
# YearBuilt             float64
# Full_Bathrooms        float64
# Half_Bathrooms        float64
# Bedrooms              float64
# Lot_Size              float64
# Story_Building        float64
# Annual_Tax            float64
# Tax_Assessed_Value    float64
# school_1_distance     float64
# school_1_rating       float64
# school_1_size         float64
# school_1_s/t_ratio    float64
# school_2_distance     float64
# school_2_rating       float64
# school_2_size         float64
# school_2_s/t_ratio    float64
# dtype: object

# %%
'''Segregate the numeric and categoric data'''
numeric_cols = X_train.select_dtypes(['float','int']).columns
categoric_cols = X_train.select_dtypes('object').columns

X_train_numeric = X_train[numeric_cols[:-1]]

X_test_numeric = X_test[numeric_cols[:-1]]

# %%
def mice_imputation_numeric(X_train_numeric, X_test_numeric):
    """
    Impute numeric data using MICE imputation with Gradient Boosting Regressor.
    """
    iter_imp_numeric = IterativeImputer(GradientBoostingRegressor())
    imputed_X_train = iter_imp_numeric.fit_transform(X_train_numeric)
    imputed_X_test = iter_imp_numeric.transform(X_test_numeric)
    X_train_numeric_imp = pd.DataFrame(imputed_X_train, columns = X_train_numeric.columns, index= X_train_numeric.index)
    X_test_numeric_imp = pd.DataFrame(imputed_X_test, columns = X_test_numeric.columns, index = X_test_numeric.index)
    return X_train_numeric_imp, X_test_numeric_imp

# %%
X_train_numeric_imp, X_test_numeric_imp = mice_imputation_numeric(X_train_numeric,X_test_numeric)

'''Concatenate Numeric and Categoric Training and Test set data '''
X_train = X_train_numeric_imp
X_test = X_test_numeric_imp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     112         try:
# --> 113             res = _encode_python(values, uniques, encode)
#     114         except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      60     if uniques is None:
# ---> 61         uniques = sorted(set(values))
#      62         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-0ddc5630c573> in <module>
#       1 X_train_numeric_imp, X_test_numeric_imp = mice_imputation_numeric(X_train_numeric,X_test_numeric)
# ----> 2 X_train_categoric_imp, X_test_categoric_imp = mice_imputation_categoric(X_train_categoric, X_test_categoric)
#       3
#       4 '''Concatenate Numeric and Categoric Training and Test set data '''
#       5 X_train = pd.concat([X_train_numeric_imp, X_train_categoric_imp, y_train], axis = 1)
#
# <ipython-input-51-716aafeaf03b> in mice_imputation_categoric(X_train_categoric, X_test_categoric)
#      23         ordinal_dict[col] = OrdinalEncoder()
#      24         nn_vals = np.array(X_train_categoric[col][X_train_categoric[col].notnull()]).reshape(-1,1)
# ---> 25         nn_vals_arr = np.array(ordinal_dict[col].fit_transform(nn_vals)).reshape(-1,)
#      26         X_train_categoric[col].loc[X_train_categoric[col].notnull()] = nn_vals_arr
#      27
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     680         self
#     681         """
# --> 682         self._fit(X)
#     683
#     684         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown)
#      84             Xi = X_list[i]
#      85             if self.categories == 'auto':
# ---> 86                 cats = _encode(Xi)
#      87             else:
#      88                 cats = np.array(self.categories[i], dtype=Xi.dtype)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     115             types = sorted(t.__qualname__
#     116                            for t in set(type(v) for v in values))
# --> 117             raise TypeError("Encoders require their input to be uniformly "
#     118                             f"strings or numbers. Got {types}")
#     119         return res
#
# TypeError: Encoders require their input to be uniformly strings or numbers. Got ['float', 'str']

# %%
X_train = X_train_numeric_imp
X_test = X_test_numeric_imp

# %%
# def standard_scale(train, test):
#     """
#     Built - in function to normalize data.
#     """
#     ss = StandardScaler()
#     xx_train, y_train = X_train[X_train.columns[:-1]], X_train[X_train.columns[-1]]
#     xx_train = pd.DataFrame(ss.fit_transform(xx_train),columns=xx_train.columns,index=xx_train.index)
#     test = pd.DataFrame(ss.transform(X_test),columns=X_test.columns,index=X_test.index)
#     return x_train, y_train, test

# x_train, y_train, test =standard_scale(X_train, X_test)

# %%
gb = xgb.XGBRegressor()

gb.fit(X_train, y_train)
pred_test = gb.predict(X_test)
pred_train = gb.predict(X_train)
# Out:
#        ZipCode   latitude  livingArea  longitude  priceChangeRate  \
# 2331   10309.0  40.529015   3420.0000 -74.241821        -0.025848
# 48902  11234.0  40.620049   1748.0000 -73.929604         0.423913
# 44575  11225.0  40.668926   2640.0000 -73.957390         1.810903
# 36963  10467.0  40.873203   1300.0000 -73.864639         0.135735
# 8943   11104.0  40.747219    952.0000 -73.915459        -0.013043
# ...        ...        ...         ...        ...              ...
# 12119  11358.0  40.753193   1936.6682 -73.785828        -0.058219
# 57191  11356.0  40.788494   2060.0000 -73.851608         0.000000
# 14147  11366.0  40.728088   1750.0000 -73.786133         0.000000
# 56088  10128.0  40.777500   8590.0000 -73.948387         0.000000
# 38408  10465.0  40.832912   1718.0000 -73.827072         0.000000
#
#        propertyTaxRate    YearBuilt  Full_Bathrooms  Half_Bathrooms  Bedrooms  \
# 2331              0.87  2007.000000        2.000000        1.000000  2.000000
# 48902             0.65  1910.000000        0.585993        1.447599  1.880779
# 44575             0.65  1920.000000        2.000000        0.000000  6.000000
# 36963             0.95  2000.000000        0.000000        0.000000  3.000000
# 8943              0.84  1925.000000        1.000000        1.000000  2.000000
# ...                ...          ...             ...             ...       ...
# 12119             0.84  1950.000000        2.000000        1.000000  4.000000
# 57191             0.84  1930.000000        3.000000        1.000000  4.000000
# 14147             0.84  1962.592962        1.000000        1.000000  3.000000
# 56088             0.88  1920.000000        0.779268        1.811252  0.295277
# 38408             0.95  1925.000000        2.000000        0.000000  4.000000
#
#        ...  Story_Building     Annual_Tax  Tax_Assessed_Value  \
# 2331   ...        2.000000    7800.000000        7.630000e+05
# 48902  ...        2.000000    7184.000000        5.890000e+05
# 44575  ...        2.000000    6151.000000        1.256000e+06
# 36963  ...        2.000000    7740.000000        7.890000e+05
# 8943   ...        2.000000    5998.000000        1.147000e+06
# ...    ...             ...            ...                 ...
# 12119  ...        1.971107    7600.000000        9.580000e+05
# 57191  ...        2.175689    6218.000000        7.840000e+05
# 14147  ...        4.162672    3526.808409        4.678029e+05
# 56088  ...        5.000000  112480.000000        2.207000e+06
# 38408  ...        2.089506    5739.000000        6.740000e+05
#
#        school_1_distance  school_1_rating  school_1_size  school_1_s/t_ratio  \
# 2331                 1.4              7.0          541.0                13.0
# 48902                0.3              4.0          731.0                15.0
# 44575                0.2              5.0          447.0                13.0
# 36963                0.2              5.0          921.0                15.0
# 8943                 0.4              8.0         1024.0                14.0
# ...                  ...              ...            ...                 ...
# 12119                0.6              7.0          676.0                16.0
# 57191                0.7              7.0         1094.0                14.0
# 14147                0.6              8.0          563.0                16.0
# 56088                0.1              6.0          513.0                13.0
# 38408                0.2              8.0          548.0                13.0
#
#        school_2_distance  school_2_rating  school_2_size
# 2331            1.300000        10.000000    1090.000000
# 48902           1.000000         5.000000     563.000000
# 44575           0.300000         6.000000     165.000000
# 36963           0.500000         2.000000     562.000000
# 8943            0.800000         8.000000     740.000000
# ...                  ...              ...            ...
# 12119           0.900000         7.000000    1058.000000
# 57191           2.800000         7.000000    1247.000000
# 14147           0.941392         8.435326    1446.970237
# 56088           0.400000         3.000000     573.000000
# 38408           0.800000         7.000000    1647.000000
#
# [49964 rows x 21 columns]

# %%
print("R2 of Y_train  GB prediction's:", r2_score(y_train, pred_train))
print("R2 of Y_test  GB prediction's:",r2_score(y_test, pred_test))
print("MAE of Y_train GB prediction's:",mean_absolute_error(y_train, pred_train))
print("MAE of Y_test GB prediction's:",mean_absolute_error(y_test, pred_test))

# %%
feature_names = X_train.columns

log_y_train = np.log(y_train)
log_y_test = np.log(y_test)

dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=feature_names)

dtest = xgb.DMatrix(X_test, label=y_test, feature_names=feature_names)

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:squarederror',
}

# %%
params['eval_metric'] = "mae"
num_boost_round = 999
evallist  = [(X_test,'eval'), (X_train,'train')]

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=10
)

print("Best MAE: {:.2f} with {} rounds".format(
                 model.best_score,
                 model.best_iteration+1))
# Out:
# [0]	Test-mae:654883.68750
# [1]	Test-mae:484606.65625
# [2]	Test-mae:379472.50000
# [3]	Test-mae:317940.84375
# [4]	Test-mae:283449.37500
# [5]	Test-mae:263806.50000
# [6]	Test-mae:252594.07812
# [7]	Test-mae:246990.67188
# [8]	Test-mae:243589.18750
# [9]	Test-mae:241531.04688
# [10]	Test-mae:239731.92188
# [11]	Test-mae:239138.25000
# [12]	Test-mae:237956.06250
# [13]	Test-mae:236344.62500
# [14]	Test-mae:236240.56250
# [15]	Test-mae:235401.98438
# [16]	Test-mae:235665.48438
# [17]	Test-mae:235259.64062
# [18]	Test-mae:235186.03125
# [19]	Test-mae:234557.65625
# [20]	Test-mae:233929.48438
# [21]	Test-mae:233517.65625
# [22]	Test-mae:233062.32812
# [23]	Test-mae:232280.00000
# [24]	Test-mae:231698.26562
# [25]	Test-mae:231888.37500
# [26]	Test-mae:231451.64062
# [27]	Test-mae:231161.68750
# [28]	Test-mae:230955.40625
# [29]	Test-mae:230755.14062
# [30]	Test-mae:230448.26562
# [31]	Test-mae:230320.28125
# [32]	Test-mae:230095.76562
# [33]	Test-mae:229850.32812
# [34]	Test-mae:229560.32812
# [35]	Test-mae:229130.53125
# [36]	Test-mae:228897.68750
# [37]	Test-mae:228786.50000
# [38]	Test-mae:228666.98438
# [39]	Test-mae:228665.25000
# [40]	Test-mae:228409.04688
# [41]	Test-mae:228537.93750
# [42]	Test-mae:228344.89062
# [43]	Test-mae:228395.76562
# [44]	Test-mae:228233.14062
# [45]	Test-mae:228252.60938
# [46]	Test-mae:227999.39062
# [47]	Test-mae:227914.57812
# [48]	Test-mae:228079.87500
# [49]	Test-mae:228075.34375
# [50]	Test-mae:228003.98438
# [51]	Test-mae:227817.82812
# [52]	Test-mae:227635.12500
# [53]	Test-mae:227444.53125
# [54]	Test-mae:227555.79688
# [55]	Test-mae:227456.87500
# [56]	Test-mae:227490.92188
# [57]	Test-mae:227403.18750
# [58]	Test-mae:227355.87500
# [59]	Test-mae:227469.07812
# [60]	Test-mae:227463.28125
# [61]	Test-mae:227583.40625
# [62]	Test-mae:227362.48438
# [63]	Test-mae:227288.45312
# [64]	Test-mae:227082.85938
# [65]	Test-mae:227106.26562
# [66]	Test-mae:227129.62500
# [67]	Test-mae:227202.56250
# 181   128750.350000     371.508705  223410.081250   3748.113289
# 182   128492.775000     487.338726  223392.362500   3725.532779
# 183   128257.620313     508.072616  223412.381250   3742.009207
# 184   128063.615625     508.016978  223384.112500   3736.736459
#
# [185 rows x 4 columns]

# %%
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(6,16)
    for min_child_weight in range(3,7)
]

# %%
min_mae = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=100,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best MAE
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with max_depth=6, min_child_weight=3
# 	MAE 224615.215625 for 146 rounds
# CV with max_depth=6, min_child_weight=4
# 	MAE 226775.14375 for 100 rounds
# CV with max_depth=6, min_child_weight=5
# 	MAE 225117.709375 for 151 rounds
# CV with max_depth=6, min_child_weight=6
# 	MAE 226382.1875 for 159 rounds
# CV with max_depth=7, min_child_weight=3
# 	MAE 224466.375 for 66 rounds
# CV with max_depth=7, min_child_weight=4
# 	MAE 224542.5125 for 111 rounds
# CV with max_depth=7, min_child_weight=5
# 	MAE 226160.096875 for 94 rounds
# CV with max_depth=7, min_child_weight=6
# 	MAE 228001.75625 for 41 rounds
# CV with max_depth=8, min_child_weight=3
# 	MAE 222500.85 for 198 rounds
# CV with max_depth=8, min_child_weight=4
# 	MAE 223994.0375 for 88 rounds
# CV with max_depth=8, min_child_weight=5
# 	MAE 224172.5375 for 100 rounds
# CV with max_depth=8, min_child_weight=6
# 	MAE 224094.15 for 96 rounds
# CV with max_depth=9, min_child_weight=3
# 	MAE 220915.159375 for 105 rounds
# CV with max_depth=9, min_child_weight=4
# 	MAE 223014.078125 for 62 rounds
# CV with max_depth=9, min_child_weight=5
# 	MAE 223796.3375 for 106 rounds
# CV with max_depth=9, min_child_weight=6
# 	MAE 223935.45625 for 87 rounds
# CV with max_depth=10, min_child_weight=3
# 	MAE 222459.3875 for 76 rounds
# CV with max_depth=10, min_child_weight=4
# 	MAE 221700.503125 for 64 rounds
# CV with max_depth=10, min_child_weight=5
# 	MAE 222650.853125 for 126 rounds
# CV with max_depth=10, min_child_weight=6
# 	MAE 223936.51875 for 40 rounds
# CV with max_depth=11, min_child_weight=3
# 	MAE 220750.609375 for 430 rounds
# CV with max_depth=11, min_child_weight=4
# 	MAE 221977.565625 for 108 rounds
# CV with max_depth=11, min_child_weight=5
# 	MAE 223834.159375 for 26 rounds
# CV with max_depth=11, min_child_weight=6
# 	MAE 223847.35625 for 74 rounds
# CV with max_depth=12, min_child_weight=3
# 	MAE 220579.884375 for 998 rounds
# CV with max_depth=12, min_child_weight=4
# 	MAE 220706.128125 for 212 rounds
# CV with max_depth=12, min_child_weight=5
# 	MAE 223829.178125 for 34 rounds
# CV with max_depth=12, min_child_weight=6
# 	MAE 223256.128125 for 41 rounds
# CV with max_depth=13, min_child_weight=3
# 	MAE 221161.540625 for 998 rounds
# CV with max_depth=13, min_child_weight=4
# 	MAE 224861.325 for 34 rounds
# CV with max_depth=13, min_child_weight=5
# 	MAE 224133.384375 for 53 rounds
# CV with max_depth=13, min_child_weight=6
# 	MAE 224761.553125 for 62 rounds
# CV with max_depth=14, min_child_weight=3
# 	MAE 221775.5375 for 998 rounds
# CV with max_depth=14, min_child_weight=4
# 	MAE 223060.8875 for 953 rounds
# CV with max_depth=14, min_child_weight=5
# 	MAE 224339.815625 for 67 rounds
# CV with max_depth=14, min_child_weight=6
# 	MAE 225775.971875 for 11 rounds
# CV with max_depth=15, min_child_weight=3
# 	MAE 223278.065625 for 903 rounds
# CV with max_depth=15, min_child_weight=4
# 	MAE 222997.975 for 591 rounds
# CV with max_depth=15, min_child_weight=5
# 	MAE 223634.096875 for 757 rounds
# CV with max_depth=15, min_child_weight=6
# 	MAE 224470.25 for 13 rounds
# Best params: 12, 3, MAE: 220579.884375

# %%
params['max_depth'] = 12
params['min_child_weight'] = 3

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_mae = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=100,
        nfold=5,
        metrics={'mae'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = (subsample,colsample)
print("Best params: {}, {}, MAE: {}".format(best_params[0], best_params[1], min_mae))
# Out:
# CV with subsample=1.0, colsample=1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-147-6154c3e7d8cc> in <module>
#      10     params['colsample_bytree'] = colsample
#      11     # Run CV
# ---> 12     cv_results = xgb.cv(
#      13         params,
#      14         dtrain,
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\training.py in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks, shuffle)
#     493         if callbacks.before_iteration(booster, i, dtrain, None):
#     494             break
# --> 495         booster.update(i, obj)
#     496
#     497         should_break = callbacks.after_iteration(booster, i, dtrain, None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\training.py in update(self, iteration, obj)
#     229         '''Iterate through folds for update'''
#     230         for fold in self.cvfolds:
# --> 231             fold.update(iteration, obj)
#     232
#     233     def eval(self, iteration, feval):
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\training.py in update(self, iteration, fobj)
#     215     def update(self, iteration, fobj):
#     216         """"Update the boosters for one iteration"""
# --> 217         self.bst.update(self.dtrain, iteration, fobj)
#     218
#     219     def eval(self, iteration, feval):
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1494
#    1495         if fobj is None:
# -> 1496             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1497                                                     ctypes.c_int(iteration),
#    1498                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
params['subsample'] = 1.0
params['colsample_bytree'] = 1.0

# %%
# %time
# This can take some time…
min_mae = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    # %time 
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=100,
            nfold=5,
            metrics=['mae'],
            early_stopping_rounds=10)
    # Update best score
    mean_mae = cv_results['test-mae-mean'].min()
    boost_rounds = cv_results['test-mae-mean'].argmin()
    print("\tMAE {} for {} rounds\n".format(mean_mae, boost_rounds))
    if mean_mae < min_mae:
        min_mae = mean_mae
        best_params = eta
print("Best params: {}, MAE: {}".format(best_params, min_mae))
# Out:
# Wall time: 0 ns
# CV with eta=0.3
# Wall time: 0 ns
# 	MAE 220579.884375 for 998 rounds
#
# CV with eta=0.2
# Wall time: 0 ns
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-779fb0bc436f> in <module>
#       9     # Run and time CV
#      10     get_ipython().run_line_magic('time', '')
# ---> 11     cv_results = xgb.cv(
#      12             params,
#      13             dtrain,
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\training.py in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks, shuffle)
#     493         if callbacks.before_iteration(booster, i, dtrain, None):
#     494             break
# --> 495         booster.update(i, obj)
#     496
#     497         should_break = callbacks.after_iteration(booster, i, dtrain, None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\training.py in update(self, iteration, obj)
#     229         '''Iterate through folds for update'''
#     230         for fold in self.cvfolds:
# --> 231             fold.update(iteration, obj)
#     232
#     233     def eval(self, iteration, feval):
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\training.py in update(self, iteration, fobj)
#     215     def update(self, iteration, fobj):
#     216         """"Update the boosters for one iteration"""
# --> 217         self.bst.update(self.dtrain, iteration, fobj)
#     218
#     219     def eval(self, iteration, feval):
#
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1494
#    1495         if fobj is None:
# -> 1496             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1497                                                     ctypes.c_int(iteration),
#    1498                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
params['eta'] = 0.05
params
# Out:
# {'max_depth': 12,
#  'min_child_weight': 3,
#  'eta': 0.05,
#  'subsample': 1.0,
#  'colsample_bytree': 1.0,
#  'objective': 'reg:squarederror',
#  'eval_metric': 'mae'}

# %%
num_boost_round = model.best_iteration + 1
best_model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")]
)
# Out:
# [0]	Test-mae:880609.81250
# [1]	Test-mae:837849.75000
# [2]	Test-mae:797665.68750
# [3]	Test-mae:759436.68750
# [4]	Test-mae:723627.18750
# [5]	Test-mae:689888.43750
# [6]	Test-mae:658109.50000
# [7]	Test-mae:628276.87500
# [8]	Test-mae:600056.43750
# [9]	Test-mae:573704.43750
# [10]	Test-mae:548817.00000
# [11]	Test-mae:525408.43750
# [12]	Test-mae:503342.31250
# [13]	Test-mae:482592.06250
# [14]	Test-mae:463158.15625
# [15]	Test-mae:444980.25000
# [16]	Test-mae:427961.90625
# [17]	Test-mae:412101.93750
# [18]	Test-mae:397160.21875
# [19]	Test-mae:383081.78125
# [20]	Test-mae:369800.06250
# [21]	Test-mae:357484.90625
# [22]	Test-mae:345993.37500
# [23]	Test-mae:335443.18750
# [24]	Test-mae:325660.50000
# [25]	Test-mae:316446.12500
# [26]	Test-mae:307880.62500
# [27]	Test-mae:300057.09375
# [28]	Test-mae:292685.68750
# [29]	Test-mae:285822.65625
# [30]	Test-mae:279358.90625
# [31]	Test-mae:273560.81250
# [32]	Test-mae:268249.28125
# [33]	Test-mae:263435.62500
# [34]	Test-mae:258954.32812
# [35]	Test-mae:254892.32812
# [36]	Test-mae:251079.62500
# [37]	Test-mae:247653.37500
# [38]	Test-mae:244537.48438
# [39]	Test-mae:241549.01562
# [40]	Test-mae:238798.90625
# [41]	Test-mae:236310.29688
# [42]	Test-mae:234082.96875
# [43]	Test-mae:231889.78125
# [44]	Test-mae:229950.54688
# [45]	Test-mae:228150.92188
# [46]	Test-mae:226551.40625
# [47]	Test-mae:225004.40625
# [48]	Test-mae:223747.56250
# [49]	Test-mae:222571.82812
# [50]	Test-mae:221416.64062
# [51]	Test-mae:220368.71875
# [52]	Test-mae:219479.35938
# [53]	Test-mae:218565.76562
# [54]	Test-mae:217774.70312
# [55]	Test-mae:217047.03125
# [56]	Test-mae:216485.50000
# [57]	Test-mae:215808.73438
# [58]	Test-mae:215241.48438
# [59]	Test-mae:214785.85938
# [60]	Test-mae:214349.17188
# [61]	Test-mae:213978.62500
# [62]	Test-mae:213629.95312
# [63]	Test-mae:213319.43750
# [64]	Test-mae:213099.23438
# [65]	Test-mae:212843.62500
# [155]	Test-mae:206566.07812
# [156]	Test-mae:206533.17188
# [157]	Test-mae:206495.04688
# [158]	Test-mae:206451.78125
# [159]	Test-mae:206409.56250
# [160]	Test-mae:206387.00000
# [161]	Test-mae:206374.76562
# [162]	Test-mae:206334.87500
# [163]	Test-mae:206307.17188
# [164]	Test-mae:206274.45312
# [165]	Test-mae:206254.95312
# [166]	Test-mae:206259.68750
# [167]	Test-mae:206251.87500
# [168]	Test-mae:206219.89062
# [169]	Test-mae:206202.01562
# [170]	Test-mae:206172.67188
# [171]	Test-mae:206134.14062
# [172]	Test-mae:206096.71875
# [173]	Test-mae:206024.79688
# [174]	Test-mae:205981.59375
# [175]	Test-mae:205976.31250
# [176]	Test-mae:205971.32812
# [177]	Test-mae:205966.98438
# [178]	Test-mae:205937.81250
# [179]	Test-mae:205927.60938
# [180]	Test-mae:205889.51562
# [181]	Test-mae:205830.98438
# [182]	Test-mae:205770.01562
# [183]	Test-mae:205712.56250
# [184]	Test-mae:205672.82812
# [185]	Test-mae:205638.32812
# [186]	Test-mae:205640.26562
# [187]	Test-mae:205629.64062
# [188]	Test-mae:205597.14062
# [189]	Test-mae:205594.04688
# [190]	Test-mae:205583.40625
# [191]	Test-mae:205539.64062
# [192]	Test-mae:205511.87500
# [193]	Test-mae:205490.78125
# [194]	Test-mae:205466.89062
# [195]	Test-mae:205421.59375
# [196]	Test-mae:205430.87500
# [197]	Test-mae:205423.37500
# [198]	Test-mae:205369.50000
# [199]	Test-mae:205327.54688
# [200]	Test-mae:205315.20312
# [201]	Test-mae:205310.79688
# [202]	Test-mae:205285.87500
# [203]	Test-mae:205258.00000
# [204]	Test-mae:205189.28125
# [205]	Test-mae:205135.90625
# [206]	Test-mae:205113.64062
# [207]	Test-mae:205088.29688
# [208]	Test-mae:205073.50000
# [209]	Test-mae:205053.68750
# [210]	Test-mae:205021.71875
# [211]	Test-mae:204981.12500
# [212]	Test-mae:204971.45312
# [213]	Test-mae:204956.62500
# [214]	Test-mae:204929.79688
# [215]	Test-mae:204921.53125
# [216]	Test-mae:204919.51562

# %%
bm_pred_test = best_model.predict(dtest)
bm_pred_train = best_model.predict(dtrain)

# %%
print("MAE of Y_train GB prediction with HP Tuning:",mean_absolute_error(log_y_train, bmlog_pred_train))
print("MAE of Y_test GB prediction with HP Tuning:",mean_absolute_error(log_y_test, bmlog_pred_test))

# %%
# Turning our prediction back to base numbers on which we did log

print("MAE of Y_train GB prediction with HP Tuning:",mean_absolute_error(y_train, bm_pred_train))

print("MAE of Y_test GB prediction with HP Tuning:",mean_absolute_error(y_test, bm_pred_test))
# Out:
# MAE of Y_train GB prediction with HP Tuning: 73672.52209371998
# MAE of Y_test GB prediction with HP Tuning: 204919.563014079

# %%
feature_important = best_model.get_score(importance_type='weight')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score")
data.plot(kind='barh')

# %%
best_model.save_model("xgb_model.model")
